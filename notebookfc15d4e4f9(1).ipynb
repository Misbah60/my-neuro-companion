# %%
import random
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# This variable stays outside the function so the AI "remembers" 
# even if you run the cell multiple times.
last_suggested_url = None

def smart_memory_companion():
    global last_suggested_url
    
    print("\n" + "═"*45)
    print("🧠 NEURO-COMPANION: ANTI-REPETITION SYSTEM")
    print("═"*45)
    
    user_text = input("I'm listening. How are you feeling? ")
    score = SentimentIntensityAnalyzer().polarity_scores(user_text)['compound']
    
    library = [
        {"vibe": "Rain & Thunderstorm", "url": "https://www.youtube.com/watch?v=lFcSrYw-ARY"},
        {"vibe": "Peaceful Forest Ambience", "url": "https://www.youtube.com/watch?v=5qap5aO4i9A"},
        {"vibe": "Deep Healing Meditation", "url": "https://www.youtube.com/watch?v=DWcLMWal874"},
        {"vibe": "Calming Piano Music", "url": "https://www.youtube.com/watch?v=W-fFHeTX70Q"},
        {"vibe": "Ocean Waves for Anxiety", "url": "https://www.youtube.com/watch?v=mXzstU76f0U"},
        {"vibe": "Lo-fi Jazz Beats", "url": "https://www.youtube.com/watch?v=4xDzrJKXOOY"},
        {"vibe": "Zen Garden Sounds", "url": "https://www.youtube.com/watch?v=662S4h6O-s8"},
        {"vibe": "Binaural Beats for Focus", "url": "https://www.youtube.com/watch?v=AImuCtIokl0"},
        {"vibe": "Soft Guitar Relaxation", "url": "https://www.youtube.com/watch?v=tck7E11SdR8"},
        {"vibe": "528Hz Miracle Tone", "url": "https://www.youtube.com/watch?v=cyEdZ23Cp1E"},
        {"vibe": "Gentle Nature Streams", "url": "https://www.youtube.com/watch?v=RnRZ_DXipgo"},
        {"vibe": "Nighttime Crickets", "url": "https://www.youtube.com/watch?v=aIIEI33EUqI"}
    ]

    if score < -0.1:
        # THE LOGIC: Keep picking until the new choice != the last choice
        choice = random.choice(library)
        while choice['url'] == last_suggested_url:
            choice = random.choice(library)
        
        # Update memory for the next time the script runs
        last_suggested_url = choice['url']
        
        print(f"\n[AI]: I've detected a low mood. I've selected some '{choice['vibe']}' for you.")
        print(f"👉 CLICK TO OPEN (Unique Link): {choice['url']}")
    else:
        print("\n[AI]: Your mood seems stable! I'm here if you need a reset later.")

# Run the model
smart_memory_companion()
# Out:
# ═════════════════════════════════════════════
# 🧠 NEURO-COMPANION: ANTI-REPETITION SYSTEM
# ═════════════════════════════════════════════
# I'm listening. How are you feeling?  i feel anxious
# [AI]: I've detected a low mood. I've selected some 'Gentle Nature Streams' for you.
# 👉 CLICK TO OPEN (Unique Link): https://www.youtube.com/watch?v=RnRZ_DXipgo

# %%
import matplotlib.pyplot as plt

# 1. We ONLY pull the columns that are pure numbers
# This avoids the error caused by the brackets [...] in your data
plot_data = df[['num_outliers', 'percent_outliers']]

# 2. Create a Bar Chart instead of a line plot
# Bar charts are much better for 'Summary' data like yours
plot_data.plot(kind='bar', figsize=(12, 6), color=['#3498db', '#e74c3c'])

plt.title("EEG Data Analysis: Outliers Detected")
plt.xlabel("Data Segment Index")
plt.ylabel("Count / Percentage")
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

print("✅ Visualization successful!")
# Out:
# ✅ Visualization successful!

# %%
import matplotlib.pyplot as plt

# This line finds the correct column for the bottom of your graph automatically
index_col = df.columns[0] 

plt.figure(figsize=(10, 6))
# We use 'num_outliers' to show the intensity of brainwave spikes
plt.fill_between(df[index_col], df['num_outliers'], color="skyblue", alpha=0.4)
plt.plot(df[index_col], df['num_outliers'], color="Slateblue", alpha=0.6, linewidth=2)

plt.title("Step 4: AI Model - Detection of Brainwave Spikes")
plt.xlabel("Data Segment (Patient Record)")
plt.ylabel("Intensity of Outliers")
plt.show()

print("✅ Step 4 Complete: Brainwave spikes visualized!")
# Out:
# ✅ Step 4 Complete: Brainwave spikes visualized!

# %% [markdown]
# Project Summary
#
#     Data Analysis: Analyzed psychiatric EEG datasets to visualize "outliers" (neurological signs of distress).
#
#     Sentiment AI: Integrated a VADER-based NLP engine to classify user mood via text input.
#
#     Smart Intervention: Built a randomized library of 10+ therapeutic resources to provide immediate, varied support.
#
#     State Management: Implemented anti-repetition logic so the AI never suggests the same link twice in a row.
#
#     Live Deployment: Transitioned from a local notebook to a live, cloud-hosted web application.
#
#  Future Work
#
#     Live EEG: Replace simulated data with Bluetooth hardware (Muse/Emotiv) for real-time brainwave tracking.
#
#     Predictive AI: Use Machine Learning to predict depressive episodes before they occur based on outlier frequency.
#
#     IoT Integration: Connect to smart home devices to automatically adjust lighting or sound when stress is detected.
#
#     Memory & Trends: Add a database to track emotional trends over weeks rather than just a single interaction.
